# %%
'''
NLP: 
  - Natural Language Processing is a sub field of Artificial Intelligence that is foucs on enabling computers to understand,
    interpret and process human languages
  - Natural Language Processing (NLP) is a field at the intersection of computer science, artificial intelligence, and 
    linguistics

# %%
'''
Application of NLP:
    - Sentiment Analysis
    - Chatbot
    - Speech Recognition
    - Machine Translation
    - Spell Checking
    - Keyword Searching
    - Information Extraction
    - Adverisement Matching
    - Siri,Alexa,or Google Assistant
    - Spam Filtering
    - Auto Complete
    - Rocognizing Named entities
    - Text Translation
    - SQl Query Generation
    - Converting Voice To text and Text To Voice
    - Speaker Identification
    - Question and answering system
    - Spelling and grammar checking

# %%
'''
Components of NLP
    - Natural Language Understanding
    - Natural Language Generation

# %%
'''
List of components of NLP?
    - Entity extraction: segmenting a sentence to identify and extract entities, such as a person (real or fictional), 
      organization, geographies, events, etc.
    - Syntactic analysis: It refers to the proper ordering of words.
    - Pragmatic analysis: Pragmatic Analysis is part of the process of extracting information from text.

# %%
'''
Natural Language Understanding(NLU):
    - NLU is defined as the process of converting NL input into useful a representation by using computational linguistics 
      tools.
    - Its about understanding of the natural language, how humans are communicating in different scenarios

# %%
'''
NLU requires following analysis to convert NL unit into a useful representation:
    1.Morphological analysis
    2.Lexical Analysis
    3.Syntactic Analysis
    4.Semantic Analysis
    5.Handling Ambiguity
    6.Discourse Integration 
    7.Pragmatic analysis

# %%
'''
Natural Language Generation(NLG):
    1.NLG is considered the second component of NLP
    2.It’s about generating new text from understanding the old data.
    3.NLG is defined as the process of generating NL by a machine as output.
    4.The output of machine should be logical output, many NLG system uses basic facts or knowledge-based representations
    
    Example: You have a system that writes an essay on a particular topic. 
             If I am instructing my machine to generate 100 words on the topic of The Cows,and my machine generates 100 words 
             on the topic of cows, then the output (here, 100 words about cows) generated by the machine should be in the form 
             of valid sentences, all sentences should be logically correct, and the context should also make sense.

# %%
Branches of NLP: NLP involves two major branches that helps us to develop NLP applications.

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %%
'''
Natural Language Inference(NLI) :
    - NLI tasks classify the relationship between a premise and hypothesis. During Inferences, a premises and Hypotheis are 
      given as input to output whether a hypothesis is true based on a given premises
      
Semantic Role Labeling(SRL): determining the replationship between a given sentences and a predicate.Such as a verb.

SQL Query Generation or Semantic parsing : Semantic Parsing helps to convert a natural language into sql queies in order to 
query a data bases.

Machine Comprehension(MC)
 : Answers questions from a paragraphs.

# %%
'''
Linguistics :
    - The Linguistics branch focuses on how NL can be analyzed using various scientific techniques. 
    - So, the Linguistics branch does scientific analysis of the form, meaning, and context.
    - All linguistics analysis can be implemented with the help of computer science techniques.
    - Here Machine Learning algorithms is a part of Computer Science, and the analysis of language is Linguistics.
    
Linguistics :linguistics is defined as the scientific study of language, including the form and syntax of language, the 
             meaning and semantics depicted by the usage of language, and the context of use.
             
What is Linguistic context?
    - In general scenario we speak or write to communicate,other people try to figureout what is objective of the sentences.
    - For Example : "What is the temperatureof India", here the user wants to know 'Temperature of india' which is context.
    - In short main objective of a sentences is context. Word or sentence surrounding spoken or written language (disclosure) 
      helps in determining the meaning of context.
    - Word2vec learns vector representation of words through the contexts.

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %%
'''

Morphology:It is branch of linguistics that studies how words can be structured and formed.

Morphemes: In linguistics, a morpheme is the smallest meaningful unit of a given language.
           The important part of morphology is morphemes
           
Stem :The part of a word that an affix is attached to is called as stem.
      The word tie is root whereas Untie is Stem
      
Morphological Analysis: It is defined as grammatical analysis of how words are formed by using morphemes. 
                        Which are the minimum unit of meaning.
                        
Generally, morphemes are affixes. Those affixes can be divided into four types.
    Prefixes : appear before a stem, such as Unhappy (un)
    Suffixes : appear after a stem, such as happiness (ness)
    Infixes : appear inside a stem, such as bumili
    Circumfixes : appear begging and end of the stem. Such as Kabaddabgan (ka******an)

# %%
'''
Morphological analysis is used in word Segmentation and Part of Speech (POS) tagging.

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %%
'''

Morphology: By definition, a morpheme is the smallest unit of language that has distinctive meaning. 
            This includes things like words, prefixes, suffixes, and so on, which have their own distinct meaning. 
            
Morphology is the study of the structure and meaning of these distinctive units or morphemes in a language. 
There are specific rules and syntaxes that govern the way morphemes can combine.

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %%
'''
Anaphora: 
    - Repetition of a word or expression at the beginning of successive phrases, clauses, sentences
    - Example : "Ram is very good in Machine Learning", he will be learning Deep learning as well
    
Meronym: 
    - Meronym is a word that denotes a constituent part or a member of something.
    - Example : apple is a meronym of apple tree
    
Holonyms: 
    - The opposite of a meronym is a holonyms - The name of the whole of which the meronym
    - Example :  Appletree is a holonym of apple
    
Entailments: 
    - An entailment is an Implication.
    - Example : Looking implies seeing, Buying Implies choosing and paying

linguistics:
    - linguistics is defined as the scientific study of language, including the form and syntax of language, the meaning and 
      semantics depicted by the usage of language, and the context of use.

Phonetics: 
    - This is the study of the acoustic properties of sounds produced by the human vocal tract during a speech

Phonology:
    - This is the study of sound patterns as interpreted in the human mind and used for distinguishing between different 
       phonemes. 

Syntax: 
    - This is usually the study of sentences, phrases, words, and their structures. This includes researching how words are 
      combined grammatically to form phrases and sentences. Syntactic order of words used in a phrase or a sentence matter 
      since the order can change the meaning entirely.

# %%
'''
Word: A word can be isolated form a sentence as the single smaller element of sentences that carries meaning.

Paragraph: 
    - A paragraph is the large unit of text handled by an NLP task.

# %%
'''
Lexical Analysis: 
    - It is defined as the process of breaking down text into words, phrases  and other meaningful elements.
    - Lexical analysis is based on word-level analysis. 
    - In this kind of analysis, we also focus on the meaning of the words, phrases and other elements, such as symbols
    
Token:
    - Token are defined as the meaningful elements that are generated by using technique of lexical analysis.
    
Syntactic Analysis:
    - Syntactic analysis is defined as analysis that tell us the logical meaning of certain given sentences or parts of 
      those sentences.
    - We also need to consider rules of grammar in order to define the logical meaning as well as correctness of the sentences
    
    - Example:
        Consider English Sentence “School go to boy”, this sentence does not logically convey its meaning, and its grammatical 
        structure is not correct.So Syntactic analyses tells us whether the given sentence convey its logical meaning and 
        whether its grammatical structure is correct.
        
Semantics: 
    - This involves the study of meaning in language and can be further subdivided into lexical and compositional semantics.
    
Semantic :
    - Study of the meaning of the words,Phrases and Sentences
    - Lexical Semantics (words and meaning relationship among words)
    - Phrasal/Sentential Semantics (Syntactics units larger than a word)
    - The study of Linguistic meaning of morphemes,words,Phrases and sentences is called semantics
    - Study of the words and their meanings in a language.
    - Focus mainly on the significace of the meaning of words in a literal sense
    
Word Semantic
    - The word semantic which means categorizing similar words together.
    - For example fruits like apple, mango, banana should be placed close whereas books will be far away from these words.
    - In a broader sense, word embedding will create the vector of fruits which will be placed far away from vector 
      representation of books.
    
Lexical semantics: 
    - This involves the study of the meanings of words and symbols using morphology and syntax.
    
Compositional semantics:
    - This involves studying relationships among words and combination of words and understanding themeaning of phrases and 
      sentences and how they are related.

Hypernym and Hyponyms:
    - Hyponymy describes the relationship between a generic term and instances of the specified generic term.
    - Here a generic term is called hypernym and instances of the generic term are called hyponyms.
    
    - Example: 
        Color is a hypernym; red, green, yellow , and so on are hyponyms

# %% [markdown]
# ![5.PNG](attachment:5.PNG)

# %%
'''
Homonyms : 
    - These are defined as words that share the same spelling or pronunciation but have different meanings.
    
    - Example : 
        “The bat hangs upside down from the tree” and “That baseball bat is really sturdy”
        
Homographs: 
    - Same spelling but different meaning and pronunciation.

Homophones:
    - These are defined as words that have the same pronunciation but have the different meanings and can have the 
      same or different spellings.
      
Heteronyms:

Heterographs:
    - These are defined as words that have the same pronunciation but different meanings as well as spellings.
    - Example : ‘to’, ’too’ and ‘two’
    
Polysemes:
    - 
    
Capitonyms: 
    - These are words  that have the same written form or spellings but have different meanings when they are capitalized.
    - Example:
        - ‘March’ indicate month and ‘march’ depicts the action of walking
        - ‘May’ indicates the month and ‘may’ depicts a modal verb
        
Synonyms:
    - These are words that have different pronunciations and spellings but the same meanings.
    - Example : ‘big’ ‘large’ and ‘huge’

Antonyms:
    - These are words defined as pairs of words that define a binary opposite relationship.

Hyponyms:
    -
    
Hypernyms:
    - 
    
Syntax:
    - This is usually study of sentences, phrases, words and their structures. 
    - this includes researching how words are combined grammatically to form phrases and sentences.
    
Lexicon:
    - This is the study of properties of words and phrases used in a language and how they build the vocabulary of the language.
    - These include what kinds of sounds are associated with meanings for words, as well as the parts of speech that words 
      belong to and their morphological.
      
Pragmatics: This is the study of how linguistic and non-linguistic factors like context and scenario might affect the
            meaning of an expression of a message or an utterance. This includes trying to infer if there are any hidden or 
            indirect meanings in communication.
            
Discourse analysis: This analyzes language and exchange of information in the form of sentences across conversations 
among human beings. These conversations could be spoken, written, or even signed.

Stylistics: This is the study of language with a focus on the style of writing including the tone, accent, dialogue, grammar, 
and type of voice.

Semiotics: This is the study of signs, symbols, and sign processes and how they communicate meaning. Things like analogies, 
metaphors, and symbolism are covered in this area.

# %%
'''
Words:
    - Smallest unit in language; they are independent and have a meaning of their own.
    - A word can be comprised of several morphemes

Words Typically fall into one of the following categories:
    1. Noun: Object or entity that could be living or non-living.
    2. Verb: Describe certain actions, states or occurrences.
    3. Adjective: Describe or qualify other words, typically nouns ad noun phrases.
    4. Adverb: Modifiers for other words including nouns, Adjectives, verbs, or other adverbs
    
Phrases: Phrases are a group of words that work together to communicate an element of speech.

Major Categories of phrases:
    1. Noun Phrases (NP)
    2. Verb Phrases (VP)
    3. Adjective Phrases (ADJP)
    4. Adverb Phrases (ADVP)
    5. Prepositional Phrases (PP)
    
Clauses:
    - Clauses can act as independent sentences, or several clauses can be combined to form a sentence.
    - Clauses are group of words with some relation between them and they usually contain subject and a predicate.
    
Categorized Clauses based on the Syntax:
    1. Declarative 
    2. Imperative
    3. Relative
    4. Interrogative
    5. Exclamative
    
Grammar:
    - Grammar helps enabling syntax and structure in language.
    - It primarily consists of a set of rules that are used to determine how to position words, phrases, and clauses when 
      constructing sentences in a natural language.
      
Grammar can be subdivided into two main class based on its representation: 
    1. Dependency Grammar
    2. Constituency Grammar

Lexical Semantic:
    - Lexical semantic is concerned with identifying semantic relationship between lexical units in a language and how they 
      are correlated to the syntax and structure of the language.
      
Lemma: 
    - It is also known as the base form for a set of words.
    
Set of words are also known as lexeme.

Example : {eating, ate, eats} which are the words forms and their lemma is the word ‘eat’

Sense or Word sense: 
    - The words have specific meaning based on their position among other words in a sentence.
    - Example : the word ‘fair’  in the following sentences.
        “They are going to annual fair” and “I hope the judgment is fair to all” 
        Even though the word ‘fair’ is the same in both sentences, the meaning changes based on the surrounding words and 
        context.
        
Corpus : It’s a collection of text document.

Text Corpora:
    - Text corpora is the plural form of ‘text corpus’ and can be defined as larger and structural collections of texts or 
      textual data.
    - They usually consist of a body of written  or spoken text. often stored in the electronic form.
    - The primary purpose of text corpora is to leverage them for linguistic as well as statistical analysis and use them as 
      data for building natural language processing tool.
    - The language data that all NLP tasks depend upon is called the text corpus or simply corpus.
    - A corpus is a large set of text data that cab be in one of the language like Englisg,French and so on.
    - The Source of the corpus the text corpus can be socila network sites like twitter,blog sites,open discussion forum like 
      stack overflow
      
Monolingual and Multilingual corpora:
    - Monolingual corpora consist of textual data in only one language and Multilingual corpora consist of textual data in 
      multiple language.  
      
Most Popular Annotations for text corpora :
    1. POS Tagging
    2. Word Stems
    3. Word lemmas
    4. Dependency grammar
    5. Constituency grammar
    6. Sematic types and roles
    
Popular Corpora : 
    1. Keyword in context
    2. Brown corpus
    3. LOB corpus
    4. Collins corpus
    5. CHILDES
    6. WordNet
    7. Penn treebanks
    8. BNC corpus
    9. ANC corpus
    10.COCA corpus
    11.Google N-gram corpus
    12.Reuters corpus
    13.Web, chat, email, tweets

# %%
'''
Various steps in while creating NLP pipeline:
    1. Sentence Segmentation
    2. Word Tokenization
    3. POS Tags (Predicting Part of Speech)
    4. Stemming
    5. Lemmatization
    6. Identifying Stop words
    7. Dependency Parsing
    8. Finding Noun Phrases
    9. Named Entity Recognition (NER)
    10.Coreference Resolution
    11.Finding Hyponyms and Hypernyms
    12.Text Normalization
    13.Reading word documents(PDF,DOCX, Plain Text files and Creating User defined corpus)
    14.Read Contents from an RSS feed
    15.HTML Parsing using Beautiful Soup
    16.Edit Distance -Writing own algorithms to find edit distance between two strings
    17.Preprocessing two short stories and extracting common vocabulary between two of them
    18.Solving text similarity problems
    19.Identifying topics
    20.Summarizing the text
    21.Resolving anaphora
    22.Disambiguating word sense

# %%
'''
Toolkit and Libraries

NLTK :The Natural Language Toolkit is a complete platform that contains over 50 corpora and lexical resources, 
such as WordNet. Besides this, it also provides the necessary tools, interfaces, and methods to process and analyze text data.

The NLTK framework comes  with a suite of efficient modules for classification, tokenization, stemming, lemmatization, 
tagging, parsing, and semantic reasoning.  It is the standard workhorse of any NLP project in the industry.

Gensim :The Gensim library has a rich set of capabilities for semantic analysis, including topic modeling and similarity 
analysis.But the best part is that it contains a Python port of Google's very popular Word2Vec model (originally available as 
a C package), which is a neural network model implemented to learn distributed representations of words where similar words 
(semantic) occur close to each other. Thus, Genism can be used for semantic analysis as well as feature engineering!

Textblob: This is another library that provides several capabilities, including text processing, phrase extraction, 
classification, POS tagging, text translation, and sentiment analysis. 
Textblob makes a lot of difficult things very easy, including language translation and sentiment analysis, by its extremely 
intuitive and easy to use API.

# %%
'''

NLP Activities:

Text Normalization: Text Wrangling (Preprocessing  or normalization) is a process that consists of a series of steps to 
wrangle, clean  and standardize textual data into a form that could be consumed by other NLP and intelligent systems 
powered by machine NLP and intelligent systems powered by machine learning and deep learning.
  
Text Processing :Text processing helps in cleaning and standardization of the text which not only helps in analytical 
systems like increasing the accuracy of classifiers, but we also get additional information and metadata in the form of 
annotations.

Basic Text Processing tasks:
    - Removing HTML tags
    - Tokenization
    - Removing unnecessary tokens and stopwords
    - Handling contractions
    - Correcting spelling errors
    - Stemming
    - Lemmatization
    - Tagging
    - Chunking
    - Parsing

What is NER :The Process of Identifying or recognizing the words in a sentence along with what they convey to the user reading 
the sentences. Such process called as NER(Named Entity Recognition).Segregating words into some predefined classes.

NER classes in Stanford NER tools :
Person; Location; Organization; Money; Percent; Date and Time

What is NER: 
    - The Process of Identifying or recognizing the words in a sentences along with what they convey to the user 
      reading the sentences.such process called as NER(Named Entity Recognition).

NER falls under the border area of information retrieval, and it is commonly known by names such as Entity identification and 
Entity Chunking and Entity Extraction.

In NER, entities are predefined categories,such as peoples names,organization names,location names,times and so on.

# %%
'''
Some of the Text Processing Tasks :

1.Tokenization:It is the process of chopping a stream of text up into words, phrases, and meaningful strings. 
  This process is called word tokenization.
  
2.Stemming : 
    - It is the process of converting each word of the sentences to its root form by deleting or replacing suffixes.
    - Stemming is the process of producing morphological variants of root/base words.
    - Examples:
        
        Ex1:“chocolates”, “chocolatey”, “Choco” to the root word, “chocolate”.
        Ex2:“retrieval”, “retrieved”, “retrieves” reduce to the stem “retrieve”.
        Ex3:"likes","liked","likely","liking" to reduce to the stem "like".
    
3. Lemmatization 
    - Lemmatization is the process of grouping together the different inflected forms of a word, so they can be analyzed as a  
      single item. 
    - Lemmatization is like stemming but it brings context to the words. so, it links words with similar meaning to one word.
    
4. Stop words :  A stop word is a commonly used word (such as “the”, “a”, “an”, “in”)

5. Handling contractions:

6. Removing HTML Tags:
    - Our text often contains unnecessary content like HTML tags, which do not add much value when analyzing text. 
      The BeautifulSoup library does an excellent job in providing necessary functions for this.
      
7. Removing special characters: 
    - Special characters and symbols that are usually non alphanumeric characters often add to the 
      extra noise in unstructured text. More often than not, simple regular expressions (regexes) can be used to achieve this.
      
Removing accented characters: 
    - In any text corpus, especially if you are dealing with the English language, you might be dealing 
      with accented characters/letters. Hence, you need to make sure that these characters are converted and standardized into 
      ASCII characters. A simple example is converting é to e.
      
Removing stopwords: 
    - Words that have little or no significance, especially when constructing meaningful features from text, 
      are known as stopwords. These are usually words that end up having the maximum frequency if you do a simple term or 
      word frequency in a corpus. Words like “a,” “an,” “the,” and so on are considered to be stopwords. 
      There is no universal stopword list, but we use a standard English language stopwords list from NLTK. 
      You can also add your own domain specific stopwords as needed.

8. POS Tagger : 
    Read the text in some language and assign part of speech to each of word(tokens), such as noun,verb,adjective

9. Chunking:

10. Parsing in NLP : 
    - Breaking a sentence as per grammar is parsing.Like a Sentence is broken into Noun Phrase and Verb Phrase.
      Noun Phrase could be again Article + Noun Such breaking of a sentence into grammar is called parsing.

11. Case Conversion

12. Dealing with Irrelevant components

13. Removing noise based on the problem to be solved

**Note :
    Accented Character :  acute (é), grave (è), circumflex (â, î or ô), tilde (ñ), umlaut and dieresis 
                          (ü or ï – the same symbol is used for two different purposes), and cedilla (ç)
                          
Removing  Accented characters:
    - In text corpus, when dealing with accented character/letters, especially if you only want to analyze to English language. 
      Hence, we need to make sure that these characters are converted and standardized into ACSII characters.

# %%
'''
Expanding Contractions: 
    - Expanding contractions: In the English language, contractions are basically shortened versions of words or syllables, 
      created by removing specific letters and sounds. 
      Examples include do not to don’t and I would to I’d. Converting each contraction to its expanded, original form often helps 
      with text standardization.

    - Contractions are shortened versions of words or syllables.
      Example : “is not” to “isn’t”   “will not” to “won’t
      
Removing Special Character: 
    - Special Character and symbols are usually non-alphanumeric characters or even occasionally numeric characters, which add 
      extra noise in unstructural text.
      
      Example : “Well this was fun! What you think? 123#”
      
Case Conversion:
    - Modify the case if words or sentences to make things easier.
      
      Example : 
        Text = ‘The quick brown fox jumped over the big Dog’
        Lower : text .lower () : ‘the quick brown fox jumped over the big dog’
        Upper :text.upper() : “THE QUICK BROWN FOX JUMPED OVER THE BIG DOG”
        Title :text.title() : ‘The Quick Brown Fix Jumped Over The Big Dog’
        
Text Correction :
    1. Correcting repeating Characters
    2. Correcting Spellings
    
Removing Stop words:
    - Stop words are words that have little or no significance and are usually removed from text when processing it to retain 
      words having maximum significance and context.
    - Example : ‘a’ ‘the’ ‘and’ 

Parts of Speech tagging(POS):
    - Parts of speech (POS) are specific lexical categories to which words are assigned based on their syntactic context and 
      role.

Hierarchical Structure of  Sentence :
    Sentences -> Clauses -> Phrases -> Words 

Feature Extraction : 
    - The process of extracting useful information from the raw data that are used to train  machine learning models.

# %%
'''

Corpus :
    - Natural language Processing related applications are built using a huge amount of data.
      You can say that large collection of data is called Corpus
    - Corpus can be collection of written or spoken natural language material, stored on computer and used to find out 
      how the language are used(Linguistic Analysis).
    
    - In order to develop NLP Applications, we need corpus that is written or spoken Natural language material. 
      We use this material or data as input data and try to find out the facts can help us develop NLP applications.

WordNet: 
    - Wordnet is an NLTK corpus reader, a lexical database for English. It can be used to find the meaning of words, Synonym 
      or antonym.

Wordnet : 
    - It is a lexical Database i.e dictionary for the English language, specifically designed for natural language processing.
    
What is Wordnet?
    - WordNet is a lexical database for the English language. 
    - It groups English words into sets of synonyms called synsets, provides short definitions and usage examples, and records 
      a number of relations among these synonym sets or their members.

Synset: 
    - It is also called as synonym set or collection of synonym word.
    
Synset : 
    - It is special kind of a simple interfaces that is present in the NLTK to lookup words in the wordnet.
    - Synset instances are the groupings of synonymous words that express the same concept. 
      Some of the words have only one Synset and some have several.
    
 
Different Types of Tokenization:
    1. Sent_Tokenize :
        - Split text into sentence
    2. Word_Tokenize :
        - Split Individual sentence into word
    3. PunctWordTokenizer : 
        - Split  sentence into word based on punctuation and punctuation are associated with word tokens
    4. WordPunctTokenizer : 
        - Split all the punctuation into separate tokens
    5. RegexTokenizer :
    6. Whitespace Tokenizer :

# %%
'''
Stemming and lemmatization: Word stems are the base form of possible words that can be created by attaching affixes like 
prefixes and suffixes to the stem to create new words. 
This is known as inflection. The reverse process of obtaining the base form of a word is known as stemming.


A simple example are the words watches, watching, and watched. They have the word root stem watch as the base form.
Lemmatization is very similar to stemming, where we remove word affixes to get to the base form of a word. 
However, the base form in this case is known as the root word but not the root stem. The difference being that the root word 
is always a lexicographically correct word (present in the dictionary) but the root stem may not always be correct.


Erros in Stemming:
    - Overstemming and Understemming.
    
Overstemming:
    - It occurs when two words are stemmed to same root that are of different stems.

Understemming:
    - It occurs when two words are stemmed to same root that are not of different stems.

Applications of stemming are:
    - Stemming is used in information retrieval systems like search engines.
    - It is used to determine domain vocabularies in domain analysis.
    
Stemming:
    - Stemming is the process of producing morphological variants of root/base words.
        Ex1:“chocolates”, “chocolatey”, “choco” to the root word, “chocolate”
        Ex2:“retrieval”, “retrieved”, “retrieves” reduce to the stem “retrieve”.
        Ex3:"likes","liked","likely","liking" reduce to the stem "like"
            
Snowballstemmber class supports 13 non-English language It provided two english stemmer that original porter stemmer as well 
as the new english stemming algorithms.

# %%
'''
POS Tagging : POS referes to categorizing the words in a sentences into specific syntactic or Grammatical functions.

Applications of POS tagging : 
    - POS tagging finds applications in Named Entity Recognization(NER),Sentiment Analysis.
    - Question Answering and Word sense disambiguation.

# %%
'''

What is Chunks :
    - Chunks are made up of words and the kinds of words are defined using the part-of-speech tags. 
      One can even define a pattern or words that can’t be a part of chuck and such words are known as chinks.

Chuncking : 
    - Chunking is used to add more structure to the sentence by following part of speech(POS) tagging. 
    - It is also known as shallow parsing. The resulted group of words is called ‘Chunks’.
    - Chunking is used for Entity Detection.

Chunking : 
    - It is the process of  extracting  short phrases from text. 
    - It will leverage POS tagging algorithms to do chunking. 
    - It uses POS tags as inputs and provides chunks as output.
    - There are standard set of chunk  tags like Noun Phrase(NP), Verb Phrase(VP), etc.
    - Chunking is very important when you want to extract information from text such as Locations, Persons names, etc.
    - We can chunking and specify specific pattern to identify what we would want to chunk or segment in a sentence.

Chinking : 
    - Chinking is the reverse process of chunking where we specify which specific tokens we do not want to be a part of any 
      chunk and then form the necessary chunks excluding these tokens. 
      
Parsing: 
    - Finding the structural relationship between words in a sentence.
    - Parsing in NLP is the process of determining the syntactic structure of a text by analyzing its constituents words 
      based on an underlaying grammar.
      
Types of Parsing algorithms :
    1. Recursive Descent parsing
    2. Shift Reduce parsing
    3. Chart Parsing
    4. Bottom-up Parsing
    5. Top-Down parsing
    6. PCFG Parsing

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %%
'''
Context Free Grammar(CFG) :
    1. Terminals (T)
    2. Non-Terminals (N)
    3. Start symbols (S)
    4. Rules (R)

Terminals : 
    - The set of words in the text

Non-Terminals : 
    - The Constituents in a language(Noun Phrases, Verb Phrases)

Start Symbol : 
    - The main constituent of the language (Sentence)

Rules : 
    - Equation that consists of a single non-terminal on the left and any number of terminals and non-terminals on the right.
    
S - > NP VP
S -> VP
NP -> N
NP -> NPNP
NP -> NP PP
VP -> V
VP -> VP PP
VP -> VP NP
PP -> Prep NP

# %%
'''
Word Embeddings : 
    - Word Embeddings are the texts converted into numbers and there may be different numerical representations of the 
      same text.
    - Neural network doesn’t understand text instead they understand only numbers.
    - Word embedding is one of the most popular representation of document vocabulary. 
    - It is capable of capturing context of a word in a document, semantic and syntactic similarity, relation with other words, 
      etc.
      
Word Embedding:
    - Word Embedding is a type of word representation that allows words with similar meaning to be understood by machine 
      learning algorithms.
    - Technically speaking, it is a mapping of words into vectors of real numbers using the neural network.
    - Word embedding is a way to perform mapping using a neural network.
    - There are various word embedding models available such as word2vec (Google), Glove (Stanford) and fastest (Facebook).
    - Word Embedding is also called as distributed semantic model or distributed represented or semantic vector space or 
      vector space model.

*** Note: The idea of Word Embeddings is to take a corpus of text, and figure out distributed vector representations of words 
          that retain some level of semantic similarity between them.
          
Where is Word Embedding used?
    - Word embedding helps in feature generation, document clustering, text classification, and natural language processing 
      tasks. Let us list them and have some discussion on each of these applications.
      
Neural Word Embeddings: 
    - The vectors we use to represent words are called neural word embeddings, and representations are strange.
    - It does so in one of two ways, either using context to predict a target word (a method known as continuous bag of words, 
      or CBOW), or using a word to predict a target context, which is called skip-gram.
    
A vector representation of a word may be a one-hot encoded vector where 1 stands for the position where the word exists and 0 
everywhere else. 
The vector representation of “numbers” in this format according to the above dictionary is [0,0,0,0,0,1] and of 
converted is[0,0,0,1,0,0].

Frequency Distribution:
    - It is used to find the frequency of each word occurring in a document.
    
Word Collocations: 
    - Collocations are the pair of words occurring together many times in a document.
    - Identifying phrases that act like single words in NLP
    - Collocations are two or more words that tend to appear frequently together, for example – United States.
    
What is N- Gram, Unigram, Bigram  and Trigram?
    - It’s about word analysis, unigram means single word, bigram means double words and trigram means triple word.
    
Categories of Collocations :
    1. Bigrams : Combination of two words
    2. Trigrams : Combination of three words
    
N Grams :
    - It refers to a sequence of n items from a given text.

N Grams : 
    - A sequence of characters or words forms an N Grams.
    - Character unigram consist of a single charcater, a bigram consists of a sequence of two characters 

Different Types of Embedding:
    1. Frequency based Embedding
    2. Prediction based Embedding
    
Frequency based Embedding :
    1. Count Vector
    2. TF-IDF Vector
    3. Co-occurrence vector
    
Count Vector :
    - Consider a Corpus C of D documents {d1,d2…..dD} and N unique tokens extracted out of the corpus C. 
    - The N tokens will form our dictionary and the size of the Count Vector matrix M will be given by D X N.
    - Each row in the matrix M contains the frequency of tokens in document D(i).
    
Prediction based Embedding:(Word2vec)

Word2vec Architecture : There are two architectures used by word2vec
    1. CBOW (Continuous Bag Of words)
    2. SKIP- Gram model
    
Word2vec : 
    - Word2vec is the technique/model to produce word embedding for better word representations. 
    - It captures a large number of precise syntactic and semantic word relationships
    - It is a shallow two- layered neural network
    - Word2vec represents words in vector space representation. 
    - Words are represented in the form of vectors and placement in done in such a way that similar words appear together and 
      dissimilar words are located far away. 
    - This is also termed as a semantic relationship.
    
Word2vec : 
    - Word2vec is a two-layer neural net that processes text.
    - Its input is a text corpus and its output is a set of vectors: feature vectors for words in that corpus.
    - While Word2vec is not a deep neural network, it turns text into a numerical form that deep nets can understand.

CBOW (Continuous Bag of Words) : 
    - In CBOW, the current word is predicted using the window of surrounding context windows.
    - CBOW model predicts the current word given context words within specific window. 
    - The input layer contains the context words and the output layer contains the current word. 
    - The hidden layer contains the number of dimensions in which we want to represent current word present at the output layer.
    - Several times faster to train than the skip-gram, slightly better accuracy for the frequent words

Skip Gram : 
    - Skip-Gram performs opposite of CBOW which implies that it predicts the given sequence or context from the word.
    - Skip gram predicts the surrounding context words within specific window given current word. 
    - The input layer contains the current word and the output layer contains the context words. 
    - The hidden layer contains the number of dimensions in which we want to represent current word present at the input layer.
    - Works well with small amount of the training data, represents well even rare words or phrases

  
Different Types of Word Embeddings :
1. Bag of Words (Bow)
2. Term Frequency - Inverse Document Frequency (TF-IDF)
3. Continuous BoW (CBOW) model and Skip Gram model embedding(Skip Gram)
4. Pre-trained word embedding models 
1. Word2Vec (by Google)
2. GloVe (by Stanford)
3. fastText (by Facebook)
     5.  Poincarré embedding
       6. Node2Vec embedding based on Random Walk and Graph

Feature engineering to represent text data.
    1. Bag of Words Model
    2. Bag of N-Gram model
    3. TF-IDF model
    4. Similarity features
    5. Topic models
    6. Word2Vec
    7. GloVe
    8. FastText
    

Which model to choose?
    - CBOW is several times faster than skip gram and provides a better frequency for frequent words whereas skip gram needs a 
      small amount of training data and represents even rare words or phrases.
      
GloVe : The Global Vectors for Word Representation

# %%
'''
The Relation between Word2Vec and NLTK?
    - NLTK is a natural language toolkit.it is used for preprocessing of text
    - Once can do different operation such as parts of speech tagging,lemmatization,stemming,stop word removal,removing rare 
      words or least used words.
    - It helps in cleaning the text as well as help in preparing the features from the effective words.

    - In the other way, word2vec is used for semantic (closely related items together) and syntactic (sequence) matching. 
      Using word2vec, one can find similar words, dissimilar words, dimensional reduction, and many others. 
      Another important feature of word2vec is to convert the higher dimensional representation of the text into lower 
      dimensional of vectors.

# %%
'''
Word Cloud:
    - Word Cloud is a data visualization technique used for representing text data in which the size of each word indicates 
      its frequency or importance. 
    - Significant textual data points can be highlighted using a word cloud. 
    - Word clouds are widely used for analyzing data from social network websites
    - Visual representaion of texts in which the sizes of the data(tokens) represnts the number of times they have 
      occured or how imporants that specific word.

Bag of word (BOW) :
    - Representing each word respect to their term frequency
    
TF-IDF (Term Frequency -Inverse document Frequency) : 
    - using this we will be able to decide how important a word is to a given document in the present dataset or corpus.
    - It indicates how many times a particular word appears in the dataset and what the important of the word is in order 
      to understand the document or dataset

One Hot Encoding :
    - One hot encoding is a process by which categorical variables are converted into a form that could be provided to ML 
      algorithms to do a better job in prediction.

# %%
'''
Example : sentence=” Word Embeddings are Word converted into numbers ”

A dictionary may be the list of all unique words in the sentence. 
So, a dictionary may look like – [‘Word’,’Embeddings’,’are’,’Converted’,’into’,’numbers’]

A vector representation of a word may be a one-hot encoded vector where 1 stands for the position where the word exists and 0 
everywhere else.

The vector representation of “numbers” in this format according to the above dictionary is [0,0,0,0,0,1] and of converted 
is [0,0,0,1,0,0].

# %%
'''
Note:

Note :The Latest semantic analysis algorithms uses ‘term frequency – Inverse document Frequency’(tf - Idf) and the concept of 
linear algebra, such as cosine similarity and Euclidean distance, to find word with similar meanings.

TF-IDF (Term Frequency -Inverse document Frequency) : using this we will be able to decide how important a word is to a given 
document in the present dataset or corpus.
It indicates how many times a particular word appears in the dataset and what the important of the word is in order to 
understand the document or dataset.

TF(t) = (Number of times term t appears in a document) / (Total number of terms in the document)

IDF(t) = log10(Total number of documents / Number of documents with term t in it)

(TF- TDF) = TF(t) * IDF(t)

Note : TF-IDF  is the multiplication of TF and IDF, such as TF * IDF

# %%
'''

Example : 
Text Document 1 : John likes to watch cricket. Chris likes cricket too

Text Document 2 : John also likes to watch movies

Based on these two text documents , you can generate the following list :
List of words : [“John”, “likes”, ”to”, ”watch”, ”cricket”, ”Chris”, ”too”, ”also”, ”movies”]

This list is called BOW.

BOW is often used to generate features; after generating BOW, we can derive the term frequency of each word in the document, 
which can later be fed to a machine learning algorithm.

For the above document ,you can generate the following frequency list:

Frequency count for Document 1 : [1,2,1,1,2,1,1,0,0]
Frequency count for Document 2 : [1,1,1,1,0,0,0,1,1]

# %%
'''

TF-IDF(Term frequency-Inverse term frequency) : tf-idf is a weighting factor which is used to get the important features from 
the documents(corpus).

It actually tells us how important a word is to a document in a corpus, the importance of a word increases proportionally to 
the number of times the word appears in the individual document, this is called Term Frequency(TF)


TfIDF Calculation

Example : document 1

“ Mady loves programming. He programs all day, he will be a world class programmer one day ”

if we apply tokenization, steeming and stopwords (we discussed in the last story) to this document, we get features with high 
count like ? program(3), day(2),love(1) and etc

TF = (no of times the word appear in the doc) / (total no of words in the doc)

Here program is the highest frequent term in the document.
so program is a good feature if we consider TF.

The inverse document frequency is a measure of how much information the word provides, that is, whether the term is common or 
rare across all documents.

IDF?—?Log(total no of documents / no of documents with the term t in it).
so TF-IDF = TF * IDF.

# %%
# Example for TF IDF

'''
Consider two sentences 

Document 1 : This is a sample
Document 2 : This is a another example

Steps to calculate TF-IDF
    1.	We first calculate the frequency of each word for each document.
    2.	We calculate IDF
    3.	We multiply TF and IDF

# %% [markdown]
# ![tfidf_01.png](attachment:tfidf_01.png)

# %%
'''

POS tags :

Tag          Description         Example
NN           Noun, Singular      Fox,Dog
NNS	Noun,    Plural              Foxes,Dogs
NNP          Proper Noun,Singular    Santhosh, Bhabesh
NNPS	Proper Noun, Plural	Indian, Germans,Kannadigas
PRP	Pronoun,personal	me,you
PRP$	Pronoun, possessive	our,my,your
VB	Verb	run, give
VBD	Verb Past Tense	ran, gave
VBG	Verb gerund/Present participle	running, giving
VBN	Verb Past Participle	given
VBP	Verb,	
		
JJ	Adjective	
JJR	Adjective, Comparative	
JJS	Adjective, Superlative	
RB	Adverb	
RBR	Adverb, Comparative	
RBS	Adverb, Superlative	
RP	Particle	
CC	Coordinating Conjunction	
CD	Cardinal number	
DT	Determiner	
Ex	Existential there	
FW	Foreign word	
IN	Preposition / Subordinating conjunction	
LS	List Item Marker	
MD	Verb Modal	
PDT	Predeterminer	
SYM	Symbol	
To	Infinitive to	
WDT	Wh-determiner	
WP	Wh-pronoun,Personal	
WP$	Wh-pronoun,Possessive	
WRB	Wh-adverb	
PP	Prepositional Phrase	
VP	Verb Phrase	
ADJP	Adjective Phrase	
ADVP	Adverb Phrase	
SBAR	Subordinating Conjunction	
PRT	Particle	
INTJ	Interjection	
PNP	Prepositional noun Phrase	
-SBJ	Sentence Subject	
-OBJ	Sentence Object

# %%
'''
What is word2vec?
    - Word2vec is the technique/model to produce word embedding for better word representation.
    - It captures a large number of precise syntactic and semantic word relationship.
    - It is a shallow two-layered neural network.

What word2vec does?
    - Word2Vector represents word in vector space representation.words are represented in the form of vectors and placement 
      is done in such a way that similar words are appear together and dissimilat words are located far away.
      This is also termed as a semantic relationship.
    - Neural networks do not understand text instead they understand only numbers.word embedding provides a way to convert 
      text to numeric vector.
    - Word2vec reconstructs the linguistic context of words.

How Word2Vec Works?
    - Work2vec learns word by predicting its surrounding context.
    - Example : "He Loves Footbal"
        - Word loves moves over each word in the corpus,Syntactic as well as the semantic relatioship berween words is encoded.
          This help in finding similar and analogies words.
        - All random features of the word loves	is calculated.These features are changed or update concerning neighbor or 
          context words with the help of a back propagation method.

Word2Vec is based on distributional hypothesis where the context for each word is in its nearby words. Hence, by looking at 
its neighbouring words, we can attempt to predict the target word.

The Word2vec representataion of words allows for exploring intersting mathematical relationships between vectors, which is also 
intutiive expression for words. Ex : we will be able to findout the value of this expreession by using word representation.

King- man = queen - woman

In the above example the word 'king' ocurs in a position aong with man, in a manner similar to how the word queen and woman 
are present with one another.


Shallow and Deep Neural Network
    - The shallow neural network consists of the only a hidden layer between input and output whereas deep neural network 
      contains multiple hidden layers between input and output.
    - Input is subjected to nodes whereas the hidden layer, as well as the output layer, contains neurons.


Another way of learning is that if the context of two words are similar or two words have similar features, 
then such words are related.


Word2vec Architecture?

# %%
'''
CFG : context-free grammar

# %%
'''
What are IOB tags?

# %%
'''
Tweet Tokenizer :
    - This is Specially designed for tokenizing tweets. it is capable of dealing with emotions and expression of sentiments, 
      which are used widely on Twitter

MWE tokenizer : 
    - MWE stands for Multi-Word Expression, here. certain group of multiple words are treated as one entity during tokenization,
      Such as "United States of America," "Peoples of Republic of China", "Not only" ,"But also"

Issues with Tokenization : 
    - Although tokenization appears to be an easy task, in reality is it not so. This is primary because of ambiguities that 
      arises due to the presence of whitespaces and hyphens .Moreover, Sentences in certain languages, such as Chinese and 
      Japanese, do not have words separated by whitespaces.

# %%
'''
Sentence Similarity:

Cosine Similarity :
    - The Cosine Similarity between two texts is the cosine of the angle between their vector representation.

Jaccard Similarity : 
    - This is the ratio of the number of terms common between two texts documents to the total number of  unique terms present 
      in those texts.
      
Levenshtein distance
    - Edit Distance between also called 'Levenshtein distance' is a metric used to measure the similarity between two distances.
      Essentially,its a count of how many edit operations,deletions,insertions,or substitutions will transform of giving string
      A to String B.

Different Ways of computing sentence similarity between two sentences

    1. Jaccard Similarity
    2. Different Embedding + K-means
    3. Different Embeddings + Cosine Similarity
    4. Word2vec + Smooth Inverse frequency + Cosine Similarity
    5. Different Embeddings + LSI + Cosine Similarity
    6. Different Embeddings + LDA + Jensen-Shannon Distance
    7. Different embeddings+ Word Mover Distance
    8. Different embeddings+ Variational Auto Encoder (VAE) 
    9. Different embeddings+ Universal sentence encoder 
    10.Different embeddings+ Siamese Manhattan LSTM
    11.Knowledge-based Measures

# %%
'''
Text Mining: 
    - It is also referred to as text data mining. 
    - It is roughly equivalent to text analysis. Is the process of driving high-quality information from the text. 
    - High-quality information is typically derived through the devising of patterns and trends through means such as 
      statistical pattern learning.
      
Text Mining Example:
    1. Risk management
    2. Knowledge Management
    3. Cybercrime preventions
    4. Customer Care Services
    5. Business Intelligence
    6. Spam Filtering

# %%
'''
Information Extraction : 
    - Information extraction is the task of automatically extracting structured information from 
    
Text Generation : Generate new text from understanding old data.

Text categorization : Identify to which category or class a specific document should be placed based on the contents of 
the documents.

Text Classification :Text classification means It will classify the text into particular class that whether it belongs to 
particular class or not

Example :Tweet classification into positive or negative

Text categorization: this will categorize text where there will be more then two class.
Example: Tweet classification into emotion. anger, joy, sad, anticipation, surprise.

Text Clustering : 
    - Automatic document organization, topic extraction, information retrieval and filtering all have one thing in common. 
      They require text clustering (sometimes also known as document clustering) to be done quickly and accurately.
      
Topic Modeling : When we have collection of documents for which we do not clearly know the categories, topic models help us 
to roughly find the categorization.

Text Summarization : the main aim of text summarization is to take a corpus of text documents, which could be a corpus of text 
documents, which could be a collection of texts ,paragraphs, sentences, and reduce the content approximately to create a 
summary that remains the key points of the collection of documents.

Summarization can be carried out by looking at the various documents and trying to find keywords, phrases, and sentences that 
have prominence in the collection.

Two main techniques of Text Summarization:
    1. Extraction based summarization
    2. Abstraction based summarization

Extractive Summarization:
    - We identify the importance sentences or phrases from the original text and extract only those from the text. 
    - Those extracted sentences would be our summary.

Abstractive Summarization : 
    - Here we generate new sentences from the original text. 
    - The sentences generated  through abstractive summarization might not be present in the original text.

Text Modeling: 
    - Topic Modeling is a technique to extract hidden topic from large volumes of text.
    - Latent Dirichlet Allocation(LDA) is a popular algorithms for topic modeling with excellent implementations in python.
    - Topic modeling capturs information about the concepts contained in a set of texts. 
    - using these concepts, documents can be organized into different categories or topics

Text Analytics:
    - Method of Extracting meaningful insights and aneswring questions from text data.
    
LSA : Latent Semantic Analysis

LDA : Latent Dirichlet Allocation
    
NER (Named Entitiy Recognization) : 
    - Process of identifying named entities(Such as proper noun)  and map them to categories 
      that are already defined.Categories might includes of persons,places, and so on

Sentiment Analysis : It tells whether the underlying sentiment is positive, negative our neutral.

Chatbot:A chatbot is a piece of software that conducts a conversation via auditory or textual methods.

# %%
'''
English Grammer:

Coordination Conjunction(CD):
    - They can join together words,pharses and independent clauses.
      Example : For;And;or;Becasue;Yet;So 
      
Correlative Conjunctions:
    - Correlative conjunctions are always used in pairs. They join similar elements.
      Ex:  both...and, not only...but also, either...or, neither...nor, whether...or.
      
Subordinating conjunction(IN): 
    - A subordinating conjunction is a word which joins together a dependent (subordinate) clause and an independent clause.
      Ex: It was snowing" is a clause; the subject is "it", "it", and the verb is "was snowing".
      
Prepositions:
    - Prepositions are a class of words that indicate relationships between nouns, pronouns and other words in a sentence
      Ex: Preposition of time (ago,before,since)
          Preposition of place (Under,Behind,between)
          Preposition of Direction (Up,Down,Over)
          Preposition of agent,instrument,devices,Machines(by,with,on)
          
Determiners(DT):
    - Determiner is a word that inroduces a noun,It always comes before the Noun,not after
          Demonstratives:- Used to show which objects are being discussed (This,That,These,Those)
          Quantifiers:-Tel How much or Hoe Many (Some,Many,A lot of,Few)
          Distributives:-Used to talk about objects in group (Each,Every)
          
Existential there(EX):
    - Existential sentence is a sentence that asserts the existence or nonexistence of something.
        Ex: There's a strange cat in the garden
        
Adjectives:
    - An adjective describes or modifies a noun. 
    - It provides further information about a noun, indicating things like size, shape, color, and more. 
        - ex: It's a big table. (size);It's an old table. (age);It's a brown table. (color)

# %%
'''
Corpus:
    #1 Looking up Synsets for a word in Wordnet
    #2 Looking up lemmas and synonyms in Wordnet
    #3 CalaculatingSynset Similarity 
    #4 Discovering the word collocations
    #5 Bigram Collaction Finder
    #5 Trigram Collaction Finder
    #6 Replacing Negations and antonyms
    #7 Replacing synonyms
    #8 Working with Hypernyms
    #9 Synset along with POS
    #10 Search for Antonyms
    #11 Get Synset Similarity
    #12 MongoDB-backed corpus reader
    #13 Similarity Measures
         - Edit distance or the Levenshtein edit distance
         - Jaccard's
         - Smith Waterman distance

Normalization :
    #1 Spelling Correction with Enchnat
    #2 Expanding Contractions
    #3 Convert to lower
    #4 Correcting the repeating Character
    #5 Remove Accented Charaters
    #6 Remove Digits
    #7 Remove Duplications
    #8 Remove Punctations
    #9 Remove Special Characters
    #10 Remove tags

Tokenization :
    #1 Tokenization text into sentence
    #2 Tokenization sentecne into words 
    #3 Tokenization Sentences using Regular Expression
    #4 Trainigsentecne tokenizer
    #5 PuncktWord Tokenizer
    #6 WordPunckt Tokenizer
    #7 WhiteSpace Tokenizer
    #8 TreebankWord Tokenizer

Stemming
    #1 Stemming words
    #2 Lemmatizing  words with WordNet
    #3 Replacing words matching regular expression
    #4 Removing Repeating Characters
    #5 Porter Stemmer
    #6 Lancaster Stemmer
    #7 RegExp Stemmer
    #8 Showball Stemmer

POSTags
    #1 Default Tagging
    #2 Standford tagger
    #3 Sequentila Tagger
         - N Gram
         - Regex Tagger
         - Affix Tagger
         - Brill Tagger
         - TnT Tagger
    #4 Machine Learning Based Tagger
    #5 Quadgram tagger
    #6 Using WordNet for tagging
    #7 Classifer-based tagger

NER
    #1 NER Tagger

Parser
    #1 A recursive descent Parser
    #2 A Shift-reduce Parser
    #3 A Chart Parser
    #4 A Regex parser
    #5 Dependency parser

Chunking
    #1 Chunking and Chinking with Regular Expression
    #2 Expanding and removing chunks with regular expression
    #3 Partial parsing with regular expression
    #4 The Chunk Score metrix
    #5 Training a tagger-based chunker
    #6 Classification based chunking
    #7 Extracting named entities
    #8 Extracting proper noun chunks
    #9 Extracting location chunks

Transforming Chunks and Trees
    #1 Filtering insignificant words from a sentence
    #2 Correcting verb forms
    #3 Swapping verb phrases
    #4 Swapping noun cardinals
    #5 Swapping infinitive phrases
    #6 Singularizing plural nouns
    #7 Chaining chunk transformations
    #8 Converting a chunk tree to text
    #9 Flattening a deep tree
    #10 Creating a shallow tree
    #11 Converting tree labels

Feature Engineering
    #1 BOW (Count Vector)
    #2 Tf-idf
    #3 CBOW
    #4 Skip Gram
    #5 One Hot Encoding

# %%
'''
LSI(Latent Semantic Indexing):

# %%
'''
1. Abbreviated Words in NLP:
    LSTM: Long Short Term Memory
    Bert: Bidirectional Encoder Representations from Transformers.
    POS: parts of speech.
    DTM: Document Term Matrix.
    NER: name entity recognition.
    NLG: Natural Language Generation.
    NLU: Natural Language Understanding.
    TF IDF: Term Frequency–Inverse Document Frequency.
    re: Regular expression.
    LDA: Latent Dirichlet Allocation.
    LSI: Latent Semantic Indexing.
    NMF: Non-Negative Matrix Factorization.
    NLTK: Natural Language Toolkit

# %%
'''
2. Some Common Steps for NLP Problems:
    Sentence Segmentation: break the text apart into separate sentences
    Tokenization: split Sentence to words
    Stemming: process of reducing words to their word stem for example thinking? think
    Lemmatizing: for example worse? bad
    POS tags: Predicting Parts of Speech for Each Token
    Identifying Stop Words: like “and”, “the”
    Name entity recognition: detect nouns with the real world concepts.
    Text classification
    Chunking
    Coreference resolution

# %%
'''
3. Applications of NLP in The Real World:
    Personal assistant applications
    Fighting spam
    Chatbots
    Managing the Advertisement
    Sentiment analysis
    Text classification
    Text summarization
    Toxicity Classification
    Name entity recognization
    Part of speech tagging
    Language model building
    Machine translation
    Spell checking
    Speech recognition
    Character recognition

# %%
'''
4. Python Library for NLP:
    NLTK
    spaCy
    Gensim : is a python library specifically for Topic Modelling.
    Pattern
    Stanford CoreNLP
    Polyglot
    TextBlob
    re: python library for regular expression
    WordCloud
    allennlp: an open-source NLP research library, built on PyTorch

# %%
'''
5. A few terms in NLP:
    Stop words
    Punctuation
    Word embedding
    Word segmentation
    Text summarization
    Regular expression
    Morphological segmentation
    Named entity recognition
    Corpus: A collection of texts
    Document-Term Matrix
    n-gram: tokenize sentences by n words combination
    Latent Dirichlet Allocation: a technique for topic modelling.

# %%
'''
6. Word Embedding Libraries:
    Word2vec
    Glove
    Fasttext
    Genism

# %%
'''
Sentiment Analysis

Sentiment analysis :Sentiment analysis is the automated process of understanding an opinion about a given subject from written 
or spoken language.

Classifying a sentence as expressing a positive, negative or neutral opinion, known as polarity classification.

Direct and Comparative Opinions

Direct opinions give an opinion about aenity directly

Example : "The picture quality of camera A is poor"

Here the direct opinion states a negative opinion about camera A.

In Comparatibe opinions, the opinion is expressed by comparing an entity with another.

Example : "The Picture quality of Camera A is better than that of Camera B"

Explicit Vs Implicit Opinions

An explicit opinion on a subject is an opinion explicitly expressed in a subjective sentence.

Example : 'The voice quality of this phone is amazing'

An implicit opinions on a subject is an opinion implied in an objective sentences.

Example: 'The earphone broke in two days'


Type of Sentiment Analysis
Polarity (positive, negative,neutral)
Detect feelings and emotions (angry,happy, sad)
Identifying Intentions (Interested, not Interested)
