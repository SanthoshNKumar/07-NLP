# %%
'''
Chatbot : Computer application that can initiate  the conversation as well as it can respond the queries as a human would do.

What is chartbot : A chat bot is computer application that mimics conversions with a human in natural language through various platforms like messaging, websites, mobiles etc

Kinds of Chatbot applications 
	- Rules Based Chatbots : Generally works on simple if-else constuctions.
	- Chatbots with Natural language understanding : Generic Chatbot, it has natural language processing and understading 
      models with pre-trained instances using Deep learning.It can communicate both through text and speech


Most chatbot architectures consist of four pillar 
    1.Intents
    2.Entities
    3.The dialog flow (State Machine)
    4.Scripts

Types of Chatbot
    - Rule Based
        - Based on if Else condition
        - Easier to build
    - Natural Language Understading Based Chatbot (AI based)
        - Natural language engine would be running
        - Intent of the customer conversion would be identified and bot will respond accordingly

Advantages of Chat bot


Uses of Chatbot
    - Customer Suppport
    - Question and Answer System (User Instrucntion of the Product)
    - Addressing Customer Complaints(Ticket addressing)
    - Appointments Booking (Hotel,Airflight,Resturents)
    
    
RASA :
    - Understanding messages and create meaningful conersations
    - Employ meachine learning to improve the those conversation

'''

# %%
'''
Components of Chatbot:

    1. Question and Answerng System
    2. Environment
    3. Front-End System
    4. Traffic Servers
    5. Custom Integration


    1. Question and Answerng System : 
            - Q & A system interprets the question and responds with relevant answers from the knowledge base. 
            - It has the following components
                  - Manual Training: 
                      - Manual training involves the domain expert creating the list of frequently asked users 
                        queries and map its answers.
                      - This helps the bot quickly identify the answers to the most important question
                  - Automated Training: 
                      - Automated training involves submitting the company’s documents like policy documents and other
                        Q&A type of documents to the bot and ask it to train itself.
                      - The engine comes up with a list of question and answers from these documents. 
                        The bot then can answer with confidence.
    2. Environment
        - NLP Engine
            - It is mainly responsible for contextualizing users’ messages using natural language processing (NLP).
            - The NLP Engine is the central component of the chatbot architecture.
            - It interprets what users are saying at any given time and turns it into organized inputs that the system 
              can process.
            - The NLP engine uses advanced machine learning algorithms to determine the user’s intent and 
              then match it to the bot’s supported intents list.
            - NLP Engine has two components:
                1. Intent Classifier:
                    Intent classifier takes users input identifies its meaning and relates back to one of the intents 
                    that the chatbot supports.
                2. Entity Extractor:
                    Entity Extractor:  Entity extractor is what extracts key information from the users query.
                    
        - Agent for Dialog Management
            - Polciy Learning
            - Feedback Mechanism from Environment
                
    3. Front-End Systems
        - Front-end systems are the ones where users interact with the chatbot.
        - These are client-facing systems such as – Facebook Messenger, WhatsApp Business, Slack, Google Hangouts, 
          your website or mobile app, etc.
        
    4. Node Server / Traffic Server
        - It is the server that deals with user traffic requests and routes them to the proper components. 
        - The response from internal components is often routed via the traffic server to the front-end systems.
        
    5. Custom Integrations
        - With custom integrations, your chatbot can be integrated with your existing backend systems like CRM, 
          database, payment apps, calendar, and many such tools, to enhance the capabilities of your chatbot
'''

# %%
'''
Intent :

Intent recognition — sometimes called intent classification — is the task of taking a written or spoken input, 
and classifying it based on what the user wants to achieve. 
Intent recognition forms an essential component of chatbots and finds use in sales conversions, customer support, 
and many other areas.

Example : 

1. For customer support, your intents might include “feature request”, “purchase”, and “account closure”

'''

'''

Entities:

Entities can be fields, data or words related to 
    date, 
    time, 
    place, 
    location, 
    description, 
    a synonym of a word, 
    a person, 
    an item, 
    a number or anything that specifies an object. 
    
The chatbots are able to identify words from users, matches the available entities or 
collects additional entities of needed to complete a task.

'''

# %%
'''
Intent : when a user interacts with a chatbot, what is the his intention to use the chat bot/ what is he asking for?

Example : When user says, "Book my movie ticket" to chatbot. This is Intent for the bot. it could be names as 'book_movie' 
        intent.
Example : When user Says, "I want to order my food" or "Can u please help order food?". These could be named as 'Order_food'

'''

# %%
'''

: Uttercases are nothing but the different form of the same question/Intent your many show.

Example : Ideal Length and Context Intention recognition 

1. When are your new product launching?
2. When i can expect to see your new product come out?
3. How long do i need to wait for your product to comeout?
4. I head that you have new product, when can i see them?

In above the questions, Intent of the question is same.

'''

# %%
'''

Understading Doamin Classifiers,Intent Classifiers and Entity Recognizers and Role Classifers

Doamin Classifiers
    - Will It rain tomorrow ? --> Domain: weather
    - Play my jazz playlist ---> Domain : Music
    
Intent Classifiers
    - Wake me up at 7AM--> Intent : set-alarm
    - Who Sings Thrillers? -->Intent : get-Artist

Entity Recognizers
    - Book a Flight to Mysore --> Entity : Mysore (Location)
    - Films with Dr Raj Kumar ---> Entity : Dr Raj Kumar (Person)   # He is a Great Person from Kannda Film Indutry
    
Role Classifers
    - Schedule a meeting from 10AM to noon --->"10AM" Role : Start 'noon' Role : end
'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
Best Chatbot/Bot Frameworks

    1. Google Dialogflow
    2. RASA NLU
    3. Wit
    4. Microsoft LUIS
    5. Botkit
    6. IBM Watson
    7. Amazon Lex
    8. Microsoft Bot Framework

'''

# %%
'''
Steps to consider while building Chatbot
    1. Deciding the scope
        - 
    2. Listing the Intents
        - Default welcome intent
        - Place order intent
        - Order staus Intent
        - order_ID
        - User Thank
    3. Listing the Entities
        - Feed_items : 
        - quantities :
        - Order_id :
'''

# %%
'''
Creating Intents and uttercases

I want food
I want order food asap
Can you please help to order food
take my order please
I want to order an food for chinse food
I want to place an order
Can you please order food for me
I want to order food
I am looking for order Thai food
I am looking to order chinse food
s
'''

# %%
'''
Different way to Build Chatbot

Cloud Based Chatbot Frameworks
    - These chatbot are designed for the user who does't have Deeplearning expertise
    - Simple and stright forward way to create chatbot
        - Dialogflow
        - Wit
        - IBM Watson
        - etc
    
Create Chatbot on our own compute hardward
    - RASA

Build-Your own Frome Scratch
    - Depth of knowledge ong ML and DL technique required
    
'''
